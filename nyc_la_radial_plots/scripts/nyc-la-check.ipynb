# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from skimage.io import imread
n = pd.read_csv('/Users/damoncrockett/images_nyc/nyc_metadata_final.csv')
PATH = '/Users/damoncrockett/images_nyc/'
def gen(series):
    for item in series:
        im = imread(PATH+item)
        yield plt.imshow(im)

# %%
g = gen(n.filename[(n.hue > 0.4) & (n.hue < .41)])

# %%
g.next()
