# %%
from skimage.io import imread

# %%
img = imread("/Users/damoncrockett/images_nyc_sample/BL2hIafCcAAPC8L.jpg")

# %%
from skimage import color

# %%
img = color.rgb2hsv(img)

# %%
img.size
# Out:
# 907500

# %%
img.shape
# Out:
# (550, 550, 3)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.imshow(img)
