# %%
import pandas as pd

# %%
df = pd.read_table('/data/damoncrockett/megacities.txt',header=False,sep="\t")

# %%
df
# Out:
#     Rank         Megacity                                            Country   \
# 0       1           Tokyo                                        Japan Japan
# 1       2         Jakarta                                Indonesia Indonesia
# 2       3           Delhi                                        India India
# 3       4           Seoul                            South Korea South Korea
# 4       5        Shanghai                                        China China
# 5       6          Mumbai                                        India India
# 6       7   New York City                        United States United States
# 7       8         Karachi                                  Pakistan Pakistan
# 8       9     Mexico City                                      Mexico Mexico
# 9      10         Beijing                                        China China
# 10     11       Sao Paulo                                      Brazil Brazil
# ...
