# %%
import pandas as pd

# %%
d = pd.read_csv('/Users/damoncrockett/Desktop/tweets.csv')

# %%
d[['WBAN','city','alt_wban','lat','lon']].head(50)
# Out:
#      WBAN         city  alt_wban        lat        lon
# 0   14821     columbus       NaN  39.938049 -82.886912
# 1   53863      atlanta       NaN  33.805219 -84.300265
# 2   14839    milwaukee       NaN  43.044368 -87.932791
# 3   13988  kansas city       NaN  39.235123 -94.567517
# 4   13893      memphis       NaN  35.123170 -89.980648
# 5   93821   louisville       NaN  38.251371 -85.757590
# 6   13988  kansas city       NaN  39.115658 -94.564520
# 7   92825        tampa       NaN  27.878393 -82.357132
# 8    3888      atlanta       NaN  33.757766 -84.401329
# 9   94846      chicago       NaN  42.008103 -87.888908
# 10  53917  new orleans       NaN  29.958088 -90.066005
# 11  94960  minneapolis       NaN  45.045398 -93.291307
# 12   3888      atlanta       NaN  33.757265 -84.401086
# 13   3929  kansas city     13988  38.914580 -94.398720
# 14  14922  minneapolis       NaN  44.982460 -93.272167
# 15  14822      detroit       NaN  42.376995 -82.930396
# ...
